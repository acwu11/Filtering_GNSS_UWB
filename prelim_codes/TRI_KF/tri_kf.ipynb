# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/TRI_KF')
sys.path.append('/content/gdrive/My Drive/TRI_KF/20210826_data')
print (sys.path)
sys.path.append('/content/gdrive/MyDrive/TRI_KF/20210826_data/Ground_Truth_Static.csv')
# Out:
# ['', '/content', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.7/dist-packages/IPython/extensions', '/root/.ipython', '/content//content/gdrive/TRI_KF', '/content//content/gdrive/TRI_KF', '/content/gdrive/My Drive/TRI_KF', '/content/gdrive/My Drive/TRI_KF', '/content/gdrive/My Drive/TRI_KF/20210826_data', '/content/gdrive/My Drive/TRI_KF', '/content/gdrive/My Drive/TRI_KF/20210826_data', '/content/gdrive/My Drive/TRI_KF', '/content/gdrive/My Drive/TRI_KF/20210826_data']

# %%
# !pip install georinex

# %%
# !python gdrive/My\ Drive/TRI_KF/main.py
# Out:
# trajectories loaded
# gdrive/My Drive/TRI_KF/main.py:45: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   cnos = np.array(cnos)
# measurements constructed
# <Figure size 640x480 with 1 Axes>
# Ranging Avg. Error: 0.7236198115164314
# entering loop
# SV ['G08' 'G10' 'G18' 'G21' 'G23' 'G24' 'G27' 'G32']
# psi (14,)
# G (7, 3)
# A (14, 7)
# SV ['G08' 'G10' 'G18' 'G21' 'G23' 'G24' 'G27' 'G32']
# psi (14,)
# G (7, 3)
# A (14, 7)
# SV ['G08' 'G10' 'G18' 'G21' 'G23' 'G24' 'G27' 'G32']
# psi (14,)
# G (7, 3)
# A (14, 7)
# SV ['G08' 'G10' 'G18' 'G21' 'G23' 'G27' 'G32']
# psi (12,)
# G (6, 3)
# A (12, 6)
# SV ['G08' 'G10' 'G18' 'G21' 'G23' 'G27' 'G32']
# psi (12,)
# G (6, 3)
# A (12, 6)
# SV ['G08' 'G10' 'G18' 'G21' 'G23' 'G27' 'G32']
# psi (12,)
# G (6, 3)
# A (12, 6)
# ...
